# %%
from src.utilities.predictionSlicing import predictionSlicing


def analyzeImage(image_path: str):
    encode_image, cont = predictionSlicing(image_path, -1, True)
    return {"message": "OK", "leaf_count": cont, "image_base64": encode_image}

# %%
IMAGE_PATH = "C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/dataset/dummy_images/imagenReal22.jpeg"


analyzeImage(IMAGE_PATH)
print("OKEY")
# Out:
# Modelo YOLO cargado exitosamente.
# Performing prediction on 9 slices.
# Visuales exportados en `C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/inference_results/debug` con prefijo `YOLO_PREDICTION_imagenReal22`
# 168
# total objetos detectados: 168
# Visuales exportados en `C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/inference_results/debug` con prefijo `YOLO_PREDICTION_imagenReal22_FILTERED`
# 10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9991
# Diagnóstico: 🌿 SANA
# Seguridad: 99.91%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9999
# Diagnóstico: 🌿 SANA
# Seguridad: 99.99%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 1.0000
# Diagnóstico: 🌿 SANA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 1.0000
# Diagnóstico: 🌿 SANA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 1.0000
# Diagnóstico: 🌿 SANA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9364
# Diagnóstico: 🌿 SANA
# Seguridad: 93.64%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 1.0000
# Diagnóstico: 🌿 SANA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.6796
# Diagnóstico: 🌿 SANA
# Seguridad: 67.96%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9970
# Diagnóstico: 🌿 SANA
# Seguridad: 99.70%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.0001
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 99.99%
# se han guardado 10 crops
# Proceso finalizado!!!
# OKEY

# %% [markdown]
# Prueba clasificador

# %%
from src.utilities.predictionSlicing import load_image_fix_orientation
from src.utilities.classifyObject import classifyObject

IMAGE_PATH = "C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/inference_results/debug/crop_1.jpg"


img = load_image_fix_orientation(IMAGE_PATH)
classifyObject(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.0365
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 96.35%
# False

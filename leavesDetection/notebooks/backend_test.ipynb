# %%
from src.utilities import HitTimer as HitTimerModule
from src.utilities.predictionSlicing import predictionSlicing

def analyzeImage(image_path: str):


    timer = HitTimerModule.HitTimer(name="analyze")

    elapsed = timer.hit()
    print(f'desde el start: "{elapsed*1000} milisegundos" desde el paso anterior')


    elapsed = timer.hit()
    print(f'una vez que recibe pasan: "{elapsed*1000} milisegundos" desde el paso anterior')

    encode_image, cont = predictionSlicing(image_path, -1, True, hit_timer=timer)
    return {"message": "OK", "leaf_count": cont, "image_base64": encode_image}

# %%
IMAGE_PATH = "../data/dataset/dummy_images/imagenReal22.jpg"


analyzeImage(IMAGE_PATH)
print("OKEY")
# Out:
# desde el start: "0.0015000005078036338 milisegundos" desde el paso anterior
# una vez que recibe pasan: "0.052200000936863944 milisegundos" desde el paso anterior
# Modelo YOLO cargado exitosamente.
# antes_de_localizar_hojas: "0.019600000086938962 milisegundos" desde el paso anterior
# Performing prediction on 48 slices.
# despues_de_localizar_hojas: "1829.4905000002473 milisegundos" desde el paso anterior
# Visuales exportados en `C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/inference_results/debug` con prefijo `YOLO_PREDICTION_imagenReal22`
# 379
# total objetos detectados: 379
# antes_de_filtrar: "228.31159999986994 milisegundos" desde el paso anterior
# despues_de_filtrar: "0.06479999865405262 milisegundos" desde el paso anterior
# Visuales exportados en `C:/Users/alexl/PycharmProjects/Trabajo_Fin_de_Grado/leavesDetection/data/inference_results/debug` con prefijo `YOLO_PREDICTION_imagenReal22_FILTERED`
# 10
# antes_de_crop_and_classify: "396.4823999995133 milisegundos" desde el paso anterior
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9956
# Diagnóstico: 🌿 SANA
# Seguridad: 99.56%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.0705
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 92.95%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.0000
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.6934
# Diagnóstico: 🌿 SANA
# Seguridad: 69.34%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.1043
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 89.57%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.5765
# Diagnóstico: 🌿 SANA
# Seguridad: 57.65%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9784
# Diagnóstico: 🌿 SANA
# Seguridad: 97.84%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.9999
# Diagnóstico: 🌿 SANA
# Seguridad: 99.99%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 1.0000
# Diagnóstico: 🌿 SANA
# Seguridad: 100.00%
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.2794
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 72.06%
# se han guardado 10 crops
# termina de clasificar las 10 hojas: "1580.1212000005762 milisegundos" desde el paso anterior
# antes_de_guardar_resultados: "68.73890000133542 milisegundos" desde el paso anterior
# despues_de_guardar_resultados: "0.1269999993382953 milisegundos" desde el paso anterior
# Proceso finalizado!!!
# OKEY

# %% [markdown]
# Prueba clasificador

# %%
from src.utilities.predictionSlicing import load_image_fix_orientation
from src.utilities.classifyObject import classifyObject

IMAGE_PATH = "../data/inference_results/debug/crop_8.jpg"


img = load_image_fix_orientation(IMAGE_PATH)
classifyObject(img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
#
# --- RESULTADO ---
# Valor numérico crudo: 0.0000
# Diagnóstico: 🍂 ENFERMA
# Seguridad: 100.00%
# False
